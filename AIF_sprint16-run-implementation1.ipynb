# %% [markdown]
# ## 課題提出時（2018/12/10）の所感
# 課題の目的はある程度達成できたと思いますが、正しくpredict出来なかったことは残念でした。

# %% [markdown]
# # 1.この課題の目的
# ・GPUを利用してみる
# ・公開されている実装を動かす際のノウハウを得る
# ・論文で読んだ手法を動かしてみる
#
# 【目的としないこと】
# ・実装を探す
# ・論文の実装を自力で行う
#
# # 2.進め方
# ・GPUの利用に慣れる（1日目〜2日目）
# ・実装を動かす（1日目〜2日目）
# sprint16ではメンターが用意したGitHubリポジトリを利用してFaster R-CNNを動かす。sprint17ではメンターによる修正が入っていないものを利用してYOLOv3を動かす。
#
# # 3.GPUを利用する
# 今後はこれまで扱ってきたものに比べ計算量が多く、データセットも巨大なものを扱っていくようになる。これを機に実務において必須であるGPUの利用に慣れることにする。
#
# 講師の指示に従い環境を整えること。

# %%
# !ls
# Out:
# annotation.txt	kaggle_simpson_testset	simpsons_dataset  train_frcnn.py
# faster_rcnn	README.md		test_frcnn.py	  Untitled.ipynb

# %%
# 学習を回してみた
# !python train_frcnn.py -p annotation.txt
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class (19 classes) :
# {'abraham_grampa_simpson': 687,
#  'apu_nahasapeemapetilon': 206,
#  'bart_simpson': 650,
#  'bg': 0,
#  'charles_montgomery_burns': 650,
#  'chief_wiggum': 209,
#  'comic_book_guy': 208,
#  'edna_krabappel': 212,
#  'homer_simpson': 718,
#  'kent_brockman': 213,
#  'krusty_the_clown': 429,
#  'lisa_simpson': 756,
#  'marge_simpson': 629,
#  'milhouse_van_houten': 210,
#  'moe_szyslak': 403,
#  'ned_flanders': 675,
#  'nelson_muntz': 219,
#  'principal_skinner': 614,
#  'sideshow_bob': 201}
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Train samples 6523, Val samples 1366
# Epoch 1/10
# ...
# 500/500 [==============================] - 383s 767ms/step - rpn_cls: 2.4803 - rpn_regr: 0.1439 - detector_cls: 2.5310 - detector_regr: 0.7482
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.654
# ...

# %%
# !pwd
# Out:
# /home/ubuntu/SimpsonRecognition

# %%
# テストしてみましたがバウンディングボックスは表示されませんでした。。
# !python test_frcnn.py -p /home/ubuntu/SimpsonRecognition/kaggle_simpson_testset
# Out:
# Using TensorFlow backend.
# abraham_grampa_simpson_1.jpg
# []
# Elapsed time = 3.9860785007476807
# abraham_grampa_simpson_12.jpg
# []
# Elapsed time = 2.131300926208496
# abraham_grampa_simpson_27.jpg
# []
# Elapsed time = 2.3679845333099365
# apu_nahasapeemapetilon_12.jpg
# []
# Elapsed time = 1.5155255794525146
# apu_nahasapeemapetilon_45.jpg
# []
# Elapsed time = 2.1414153575897217
# bart_simpson_32.jpg
# []
# Elapsed time = 1.1124489307403564
# charles_montgomery_burns_27.jpg
# []
# Elapsed time = 1.1481568813323975
# chief_wiggum_25.jpg
# []
# Elapsed time = 1.9947881698608398
# comic_book_guy_21.jpg
# []
# Elapsed time = 1.100806474685669
# comic_book_guy_5.jpg
# [('marge_simpson', 73.7655758857727)]
# Elapsed time = 1.1034231185913086
# edna_krabappel_18.jpg
# []
# Elapsed time = 1.1754953861236572
# homer_simpson_18.jpg
# []
# Elapsed time = 1.1345231533050537
# homer_simpson_44.jpg
# []
# Elapsed time = 2.1274919509887695
# kent_brockman_16.jpg
# []
# ...
